# %% [markdown]
# # Paired Label-Budget Benchmark
#
# Run the strict holdout label-budget curve from inside the notebook.

# %%
from pathlib import Path
import sys

repo_root = Path('..').resolve() if Path.cwd().name == 'notebooks' else Path('.').resolve()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
if str(repo_root / 'src') not in sys.path:
    sys.path.insert(0, str(repo_root / 'src'))

from crash_tests.ml_statistics_workbench.label_budget import LabelBudgetConfig, run_with_config

# %%
RUN_NAME = 'label_budget_full_v1'
SMOKE_RUN = False

config = LabelBudgetConfig(
    parquet_path=repo_root / 'data/raw/33000_ROWS.parquet',
    output_root=repo_root / 'crash_tests/ml_statistics_workbench/outputs',
    run_name=RUN_NAME,
    verbose=True,
)
if SMOKE_RUN:
    config.budgets = (20, 60, 107)
    config.repeats = 2
config

# %%
output_dir = run_with_config(config)
output_dir

# %%
import pandas as pd
curve = pd.read_csv(output_dir / "budget_curve_summary.csv")
recommend = pd.read_csv(output_dir / "budget_recommendation.csv")
display(recommend)
display(curve.sort_values(["target", "budget_rows", "mean_r2"], ascending=[True, True, False]))
